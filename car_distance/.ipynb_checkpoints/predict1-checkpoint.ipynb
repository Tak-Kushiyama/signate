# %% [markdown]
# # Signate【練習問題】自動車の走行距離予測

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### ファイル読み込み

# %%
train = pd.read_csv('train.tsv', delimiter='\t')
test = pd.read_csv('test.tsv', delimiter='\t')
sample = pd.read_csv('sample_submit.csv', header = None)

# %%
train.head()
# Out:
#    id   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   0  29.0          4         135.0      84.00  2525.0          16.0
# 1   3  31.9          4          89.0      71.00  1925.0          14.0
# 2   9  19.0          6         156.0      108.0  2930.0          15.5
# 3  11  28.0          4          90.0      75.00  2125.0          14.5
# 4  13  37.7          4          89.0      62.00  2050.0          17.3
#
#    model year  origin          car name
# 0          82       1    dodge aries se
# 1          79       2  vw rabbit custom
# 2          76       3    toyota mark ii
# 3          74       1        dodge colt
# 4          81       3     toyota tercel

# %%
test.head()
# Out:
#    id  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0   1          6         145.0      76.00  3160.0          19.6          81
# 1   2          6         250.0      98.00  3525.0          19.0          77
# 2   4          4         119.0      92.00  2434.0          15.0          80
# 3   5          6         258.0      110.0  2962.0          13.5          71
# 4   6          4          97.0      88.00  2100.0          16.5          72
#
#    origin                    car name
# 0       2                volvo diesel
# 1       1                ford granada
# 2       3        datsun 510 hatchback
# 3       1  amc hornet sportabout (sw)
# 4       3    toyota corolla 1600 (sw)

# %%
sample.head()
# Out:
#    0     1
# 0  1  19.8
# 1  2  31.3
# 2  4  31.9
# 3  5  20.0
# 4  6  16.5

# %% [markdown]
# ### 可視化

# %%
train.corr()
# Out:
#                     id       mpg  cylinders  displacement    weight  \
# id            1.000000 -0.052688   0.103419      0.098416  0.070563
# mpg          -0.052688  1.000000  -0.770160     -0.804635 -0.820660
# cylinders     0.103419 -0.770160   1.000000      0.950600  0.893256
# displacement  0.098416 -0.804635   0.950600      1.000000  0.933038
# weight        0.070563 -0.820660   0.893256      0.933038  1.000000
# acceleration -0.087649  0.379721  -0.479561     -0.523955 -0.401757
# model year   -0.093272  0.568471  -0.303462     -0.329817 -0.265562
# origin       -0.031421  0.533671  -0.497373     -0.579805 -0.535893
#
#               acceleration  model year    origin
# id               -0.087649   -0.093272 -0.031421
# mpg               0.379721    0.568471  0.533671
# cylinders        -0.479561   -0.303462 -0.497373
# displacement     -0.523955   -0.329817 -0.579805
# weight           -0.401757   -0.265562 -0.535893
# acceleration      1.000000    0.194854  0.189193
# model year        0.194854    1.000000  0.124279
# origin            0.189193    0.124279  1.000000

# %% [markdown]
# ### 特徴量の追加 (移動平均追加)

# %%
train["temp_ma5"] = train["temp"].rolling(5).mean()
train["temp_ma10"] = train["temp"].rolling(10).mean()
train["temp_ma15"] = train["temp"].rolling(15).mean()
train["temp_ma20"] = train["temp"].rolling(20).mean()

train["atemp_ma5"] = train["atemp"].rolling(5).mean()
train["atemp_ma10"] = train["atemp"].rolling(10).mean()
train["atemp_ma15"] = train["atemp"].rolling(15).mean()
train["atemp_ma20"] = train["atemp"].rolling(20).mean()

train["hum_ma5"] = train["hum"].rolling(5).mean()
train["hum_ma10"] = train["hum"].rolling(10).mean()
train["hum_ma15"] = train["hum"].rolling(15).mean()
train["hum_ma20"] = train["hum"].rolling(20).mean()

# %%
train.head()
# Out:
#    id      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0   1  2011-01-01       1   0     1   0        0        6           0
# 1   2  2011-01-01       1   0     1   1        0        6           0
# 2   3  2011-01-01       1   0     1   2        0        6           0
# 3   4  2011-01-01       1   0     1   3        0        6           0
# 4   5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  ...  temp_ma15  temp_ma20  atemp_ma5  atemp_ma10  atemp_ma15  \
# 0           1  ...        NaN        NaN        NaN         NaN         NaN
# 1           1  ...        NaN        NaN        NaN         NaN         NaN
# 2           1  ...        NaN        NaN        NaN         NaN         NaN
# 3           1  ...        NaN        NaN        NaN         NaN         NaN
# 4           1  ...        NaN        NaN    0.28182         NaN         NaN
#
#    atemp_ma20  hum_ma5  hum_ma10  hum_ma15  hum_ma20
# 0         NaN      NaN       NaN       NaN       NaN
# 1         NaN      NaN       NaN       NaN       NaN
# 2         NaN      NaN       NaN       NaN       NaN
# 3         NaN      NaN       NaN       NaN       NaN
# 4         NaN    0.782       NaN       NaN       NaN
#
# [5 rows x 27 columns]

# %%
test["temp_ma5"] = test["temp"].rolling(5).mean()
test["temp_ma10"] = test["temp"].rolling(10).mean()
test["temp_ma15"] = test["temp"].rolling(15).mean()
test["temp_ma20"] = test["temp"].rolling(20).mean()

test["atemp_ma5"] = test["atemp"].rolling(5).mean()
test["atemp_ma10"] = test["atemp"].rolling(10).mean()
test["atemp_ma15"] = test["atemp"].rolling(15).mean()
test["atemp_ma20"] = test["atemp"].rolling(20).mean()

test["hum_ma5"] = test["hum"].rolling(5).mean()
test["hum_ma10"] = test["hum"].rolling(10).mean()
test["hum_ma15"] = test["hum"].rolling(15).mean()
test["hum_ma20"] = test["hum"].rolling(20).mean()

# %%
test.head()
# Out:
#      id      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0  8646  2012-01-01       1   1     1   0        0        0           0
# 1  8647  2012-01-01       1   1     1   1        0        0           0
# 2  8648  2012-01-01       1   1     1   2        0        0           0
# 3  8649  2012-01-01       1   1     1   3        0        0           0
# 4  8650  2012-01-01       1   1     1   4        0        0           0
#
#    weathersit  ...  temp_ma15  temp_ma20  atemp_ma5  atemp_ma10  atemp_ma15  \
# 0           1  ...        NaN        NaN        NaN         NaN         NaN
# 1           1  ...        NaN        NaN        NaN         NaN         NaN
# 2           1  ...        NaN        NaN        NaN         NaN         NaN
# 3           1  ...        NaN        NaN        NaN         NaN         NaN
# 4           1  ...        NaN        NaN    0.34242         NaN         NaN
#
#    atemp_ma20  hum_ma5  hum_ma10  hum_ma15  hum_ma20
# 0         NaN      NaN       NaN       NaN       NaN
# 1         NaN      NaN       NaN       NaN       NaN
# 2         NaN      NaN       NaN       NaN       NaN
# 3         NaN      NaN       NaN       NaN       NaN
# 4         NaN     0.74       NaN       NaN       NaN
#
# [5 rows x 26 columns]

# %%
train['temp_ma5'].head(20)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4     0.232
# 5     0.232
# 6     0.232
# 7     0.228
# 8     0.228
# 9     0.244
# 10    0.272
# 11    0.300
# 12    0.344
# 13    0.388
# 14    0.416
# 15    0.428
# 16    0.440
# 17    0.444
# 18    0.436
# 19    0.428
# Name: temp_ma5, dtype: float64

# %%
plt.figure(figsize = (12,5))
plt.plot(train.index, train['temp_ma5'], label='ma5')
plt.plot(train.index, train['temp_ma10'], label='ma10')
plt.plot(train.index, train['temp_ma15'], label='ma15')
plt.plot(train.index, train['temp_ma20'], label='ma20')

plt.legend()
plt.grid()

# %%
train['temp_diff'] = train['temp'].diff()
train['atemp_diff'] = train['atemp'].diff()
train['hum_diff'] = train['hum'].diff()

test['temp_diff'] = test['temp'].diff()
test['atemp_diff'] = test['atemp'].diff()
test['hum_diff'] = test['hum'].diff()

# %%
train.head(5)
# Out:
#    id      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0   1  2011-01-01       1   0     1   0        0        6           0
# 1   2  2011-01-01       1   0     1   1        0        6           0
# 2   3  2011-01-01       1   0     1   2        0        6           0
# 3   4  2011-01-01       1   0     1   3        0        6           0
# 4   5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  ...  atemp_ma10  atemp_ma15  atemp_ma20  hum_ma5  hum_ma10  \
# 0           1  ...         NaN         NaN         NaN      NaN       NaN
# 1           1  ...         NaN         NaN         NaN      NaN       NaN
# 2           1  ...         NaN         NaN         NaN      NaN       NaN
# 3           1  ...         NaN         NaN         NaN      NaN       NaN
# 4           1  ...         NaN         NaN         NaN    0.782       NaN
#
#    hum_ma15  hum_ma20  temp_diff  atemp_diff  hum_diff
# 0       NaN       NaN        NaN         NaN       NaN
# 1       NaN       NaN      -0.02     -0.0152     -0.01
# 2       NaN       NaN       0.00      0.0000      0.00
# 3       NaN       NaN       0.02      0.0152     -0.05
# 4       NaN       NaN       0.00      0.0000      0.00
#
# [5 rows x 30 columns]

# %%
train['temp_diff7'] = train['temp'].diff(7)
train['atemp_diff7'] = train['atemp'].diff(7)
train['hum_diff7'] = train['hum'].diff(7)

test['temp_diff7'] = test['temp'].diff(7)
test['atemp_diff7'] = test['atemp'].diff(7)
test['hum_diff7'] = test['hum'].diff(7)

# %%
train.corr()
# Out:
#                    id    season  yr      mnth        hr   holiday   weekday  \
# id           1.000000  0.824925 NaN  0.996461 -0.008772  0.031203  0.010960
# season       0.824925  1.000000 NaN  0.829054 -0.012179 -0.001116 -0.013639
# yr                NaN       NaN NaN       NaN       NaN       NaN       NaN
# mnth         0.996461  0.829054 NaN  1.000000 -0.011814  0.029806  0.012024
# hr          -0.008772 -0.012179 NaN -0.011814  1.000000 -0.000929 -0.005618
# holiday      0.031203 -0.001116 NaN  0.029806 -0.000929  1.000000 -0.076324
# weekday      0.010960 -0.013639 NaN  0.012024 -0.005618 -0.076324  1.000000
# workingday   0.003052  0.013763 NaN  0.003573  0.003792 -0.247934  0.018572
# weathersit  -0.020071 -0.015351 NaN -0.020662 -0.016521  0.008001  0.027766
# temp         0.259605  0.343535 NaN  0.260442  0.120548 -0.020059 -0.038969
# atemp        0.271344  0.351910 NaN  0.272676  0.116382 -0.026915 -0.042439
# hum          0.188215  0.191793 NaN  0.188061 -0.251188 -0.022895 -0.051307
# windspeed   -0.154082 -0.154735 NaN -0.155645  0.125153  0.000502  0.039586
# hum_ma20     0.964784  1.000000   0.069262    0.047275 -0.120167    0.124748
# temp_diff    0.166859  0.069262   1.000000    0.830076 -0.669902    0.458456
# atemp_diff   0.122252  0.047275   0.830076    1.000000 -0.546021    0.366359
# hum_diff    -0.186517 -0.120167  -0.669902   -0.546021  1.000000   -0.306629
# temp_diff7   0.205540  0.124748   0.458456    0.366359 -0.306629    1.000000
# atemp_diff7  0.172926  0.099718   0.437789    0.410090 -0.282012    0.950587
# hum_diff7   -0.250810 -0.206469  -0.339830   -0.269977  0.409090   -0.785797
#
#              atemp_diff7  hum_diff7
# id             -0.004269   0.000480
# season         -0.005060   0.000791
# yr                   NaN        NaN
# mnth           -0.004461   0.000789
# hr              0.136907  -0.117348
# holiday        -0.015838   0.012753
# weekday        -0.021300  -0.003923
# workingday     -0.015727  -0.024022
# weathersit     -0.051401   0.117755
# temp            0.213546  -0.184930
# atemp           0.231556  -0.167187
# hum            -0.368485   0.503048
# windspeed       0.052660  -0.261767
# cnt             0.383269  -0.355438
# temp_ma5        0.094211  -0.089130
# temp_ma10      -0.052523   0.032861
# temp_ma15      -0.099105   0.064980
# temp_ma20      -0.072073   0.030837
# atemp_ma5       0.102628  -0.076016
# atemp_ma10     -0.051088   0.038097
# atemp_ma15     -0.097224   0.065381
# atemp_ma20     -0.071153   0.030813
# hum_ma5        -0.171626   0.232795
# hum_ma10        0.088389  -0.119834
# hum_ma15        0.172926  -0.250810
# hum_ma20        0.099718  -0.206469
# temp_diff       0.437789  -0.339830
# atemp_diff      0.410090  -0.269977
# hum_diff       -0.282012   0.409090
# temp_diff7      0.950587  -0.785797
# atemp_diff7     1.000000  -0.727192
# hum_diff7      -0.727192   1.000000
#
# [32 rows x 32 columns]

# %% [markdown]
# ### モデルの準備

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
model = xgb.XGBRegressor()

# %%
train = train.drop(['yr', 'id', 'dteday'], axis = 1)
test = test.drop(['yr', 'id', 'dteday'], axis = 1)

# %%
trainX = train.copy()
y = train['cnt']
trainX = train.drop('cnt', axis=1)
testX = test.copy()

# %% [markdown]
# ### パラメータのサーチ

# %%
gcv = GridSearchCV(model, {'max_depth': [6], 'n_estimators': [50,100,200]}, verbose=1, n_jobs=-1, return_train_score=True)

# %%
gcv.fit(trainX, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              n_jobs=-1,
#              param_grid={'max_depth': [6], 'n_estimators': [50, 100, 200]},
#              return_train_score=True, verbose=1)

# %%
gcv.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 50}

# %% [markdown]
# ### ベストパラメータで改めてモデル作成

# %% [markdown]
# ### 訓練データで精度チェック

# %%
pred_train = gcv.predict(trainX)

# %%
train_value = y.values
_df = pd.DataFrame({'actual':train_value,'pred':pred_train})
_df.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### テストデータで予測

# %%
pred_test =  gcv.predict(testX)

# %%
pred_test
# Out:
# array([25.583874, 58.57775 , 45.152294, ..., 62.305084, 49.882137,
#        12.152622], dtype=float32)

# %%
i = 0
for d in pred_test:
    if d < 0:
        d = 0
    pred_test[i] = d
    i = i + 1

# %%
sample[1] = pred_test

# %%
sample.to_csv('submit4.csv', header=None, index=None)
